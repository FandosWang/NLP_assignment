# %% [markdown]
# ## Lesson-01 Assignment

# %% [markdown]
# >

# %% [markdown]
# `各位同学大家好，欢迎各位开始学习我们的人工智能课程。这门课程假设大家不具备机器学习和人工智能的知识，但是希望大家具备初级的Python编程能力。根据往期同学的实际反馈，我们课程的完结之后 能力能够超过80%的计算机人工智能/深度学习方向的硕士生的能力。`

# %% [markdown]
# ## 本次作业的内容

# %% [markdown]
# #### 1. 复现课堂代码
#
# 在本部分，你需要参照我们给大家的GitHub地址里边的课堂代码，结合课堂内容，复现内容。

# %%
simple_grammar = """
sentence => noun_phrase verb_phrase
noun_phrase => Article Adj* noun
Adj* => null | Adj Adj*
verb_phrase => verb noun_phrase
Article =>  一个 | 这个
noun =>   女人 |  篮球 | 桌子 | 小猫
verb => 看着   |  坐在 |  听着 | 看见
Adj =>  蓝色的 | 好看的 | 小小的
"""

# %%
def create_grammar(grammar_str, split='=>', line_split='\n'):
    grammar = {}
    for line in grammar_str.split(line_split):
        if not line.strip(): continue
        gram, exam = line.split(split)
        grammar[gram.strip()] = [s.split() for s in exam.split('|')]
    return grammar

# %%
grammar = create_grammar(simple_grammar)
print(grammar)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-0c56ebd17162> in <module>
# ----> 1 grammar = create_grammar(simple_grammar)
#       2 print(grammar)
#
# NameError: name 'create_grammar' is not defined

# %%
assert 'noun_phrase' in grammar

# %%
import random
choice = random.choice
def generate(gram, target):
    if target not in gram: return target
    expand = [generate(gram, t) for t in choice(gram[target])]
    return ''.join(s for s in expand if s != 'null')
    #return ''.join([s if s != '\n' else '/n' for s in expand if s != 'null'])

# %%
generate(grammar,'sentence')

# %%
for n in range(20):
    print(generate(create_grammar(simple_grammar), 'sentence'))
# Out:
# 一个小小的小小的蓝色的蓝色的小猫看着一个蓝色的小猫
# 一个小猫听着这个小小的蓝色的小猫
# 一个小猫看着这个小小的小小的小猫
# 这个篮球坐在这个小猫
# 一个蓝色的小小的蓝色的小猫听着这个桌子
# 一个小小的小小的篮球看见这个小小的女人
# 这个桌子听着这个蓝色的小猫
# 这个好看的蓝色的蓝色的小小的蓝色的蓝色的蓝色的女人听着一个篮球
# 一个小小的好看的好看的蓝色的女人看见这个小小的蓝色的小猫
# 这个桌子听着这个小小的蓝色的女人
# 一个桌子看着这个篮球
# 这个篮球听着一个小小的篮球
# 一个小小的女人看着一个桌子
# 一个女人坐在这个小猫
# 一个蓝色的蓝色的好看的篮球坐在一个桌子
# 这个小小的好看的好看的小小的小小的篮球听着一个好看的小小的小小的蓝色的好看的好看的桌子
# 这个篮球看着一个小小的小小的蓝色的女人
# 这个篮球看着一个小小的女人
# 这个桌子看着这个小小的篮球
# 这个小猫看着一个小猫

# %%
#在西部世界里，一个”人类“的语言可以定义为：

human = """
human = 自己 寻找 活动
自己 = 我 | 俺 | 我们 
寻找 = 找找 | 想找点 
活动 = 乐子 | 玩的
"""


#一个“接待员”的语言可以定义为

host = """
host = 寒暄 报数 询问 业务相关 结尾 
报数 = 我是 数字 号 ,
数字 = 单个数字 | 数字 单个数字 
单个数字 = 1 | 2 | 3 | 4 | 5 | 6 | 7 | 8 | 9 
寒暄 = 称谓 打招呼 | 打招呼
称谓 = 人称 ,
人称 = 先生 | 女士 | 小朋友
打招呼 = 你好 | 您好 
询问 = 请问你要 | 您需要
业务相关 = 玩玩 具体业务
玩玩 = null
具体业务 = 喝酒 | 打牌 | 打猎 | 赌博
结尾 = 吗？
"""

# %%
for i in range(20):
    print(generate(create_grammar(host, split='='), 'host'))
# Out:
# 你好我是16号,请问你要打猎吗？
# 小朋友,你好我是332号,您需要打猎吗？
# 您好我是97号,您需要打猎吗？
# 您好我是9号,您需要打猎吗？
# 先生,您好我是2号,请问你要打猎吗？
# 女士,你好我是9号,请问你要打猎吗？
# 小朋友,你好我是656号,请问你要打牌吗？
# 先生,您好我是95号,请问你要赌博吗？
# 小朋友,您好我是4号,请问你要打猎吗？
# 小朋友,你好我是6号,请问你要打牌吗？
# 小朋友,你好我是1号,请问你要打牌吗？
# 你好我是84号,您需要赌博吗？
# 先生,你好我是2号,您需要打牌吗？
# 你好我是4876号,请问你要喝酒吗？
# 您好我是779357号,您需要打猎吗？
# 您好我是675号,您需要打猎吗？
# 你好我是6号,您需要打牌吗？
# 你好我是8号,请问你要赌博吗？
# 您好我是5号,请问你要赌博吗？
# 先生,您好我是8484号,您需要打猎吗？

# %%
import pandas as pd

filename = 'article_9k.txt' 
with open(filename, 'r') as f:
# Out:
# 151

# %%
# Out:
# Assignment-01.ipynb article_9k.txt

# %% [markdown]
# #### 2. 请回答以下问题
#
# 回答以下问题，并将问题发送至 mqgao@kaikeba.com中：
# ```
#     2.1. what do you want to acquire in this course？
#         Ans: I want to learn the basic skills and knowledge that a NLP engineer should have.
#     2.2. what problems do you want to solve？
#         Ans: Translation problem and man-machine conversation system
#     2.3. what’s the advantages you have to finish you goal?
#         Ans: I don't have any advantages at all, so I should work harder than others.
#     2.4. what’s the disadvantages you need to overcome to finish you goal?
#         Ans: Python programming skill and math
#     2.5. How will you plan to study in this course period?
#         Ans: Step with my teachers and finish all assignments.
# ```

# %% [markdown]
# #### 3. 如何提交
# 代码 + 此 jupyter 相关，提交至自己的 github 中(**所以请务必把GitHub按照班主任要求录入在Trello中**)；
# 第2问，请提交至mqgao@kaikeba.com邮箱。
# #### 4. 作业截止时间
# 此次作业截止时间为 2019.7.6日

# %% [markdown]
# #### 5. 完成以下问答和编程练习

# %% [markdown]
# >

# %% [markdown]
# ## 基础理论部分

# %% [markdown]
# #### 0. Can you come up out 3 sceneraies which use AI methods?

# %% [markdown]
# Ans: Translation, question-answer system,auto-driving.

# %% [markdown]
# #### 1. How do we use Github; Why do we use Jupyter and Pycharm;

# %% [markdown]
# Ans: We use Github to save and download files. We use Jupyter and Pycharm because we choose python to accomplish our AI assignment. For python, Jupyter is suitable for demo and Pycharm is suitable for large engineering project.

# %% [markdown]
# #### 2. What's the Probability Model?

# %% [markdown]
# Ans:Probabillity Model is a model that make a best choice based on the probalillity.

# %% [markdown]
# #### 3. Can you came up with some sceneraies at which we could use Probability Model?

# %% [markdown]
# Ans: question-answer system, searching, recommend system.

# %% [markdown]
# #### 4. Why do we use probability and what's the difficult points for programming based on parsing and pattern match?

# %% [markdown]
# Ans:

# %% [markdown]
# #### 5. What's the Language Model;

# %% [markdown]
# Ans:

# %% [markdown]
# #### 6. Can you came up with some sceneraies at which we could use Language Model?

# %% [markdown]
# Ans:

# %% [markdown]
# #### 7. What's the 1-gram language model;

# %% [markdown]
# Ans:

# %% [markdown]
# #### 8. What's the disadvantages and advantages of 1-gram language model;

# %% [markdown]
# Ans:

# %% [markdown]
# #### 9. What't the 2-gram models;

# %% [markdown]
# Ans:

# %% [markdown]
# ## 编程实践部分

# %% [markdown]
# #### 1. 设计你自己的句子生成器

# %% [markdown]
# 如何生成句子是一个很经典的问题，从1940s开始，图灵提出机器智能的时候，就使用的是人类能不能流畅和计算机进行对话。和计算机对话的一个前提是，计算机能够生成语言。
#
# 计算机如何能生成语言是一个经典但是又很复杂的问题。 我们课程上为大家介绍的是一种基于规则（Rule Based）的生成方法。该方法虽然提出的时间早，但是现在依然在很多地方能够大显身手。值得说明的是，现在很多很实用的算法，都是很久之前提出的，例如，二分查找提出与1940s, Dijstra算法提出于1960s 等等。

# %% [markdown]
# 在著名的电视剧，电影《西部世界》中，这些机器人们语言生成的方法就是使用的SyntaxTree生成语言的方法。
#
# >
# >
#
# ![WstWorld](https://timgsa.baidu.com/timg?image&quality=80&size=b10000_10000&sec=1561818705&di=95ca9ff2ff37fcb88ae47b82c7079feb&src=http://s7.sinaimg.cn/mw690/006BKUGwzy75VK46FMi66&690)
#
# >
# >

# %% [markdown]
# 在这一部分，需要各位同学首先定义自己的语言。 大家可以先想一个应用场景，然后在这个场景下，定义语法。例如：
#
# 在西部世界里，一个”人类“的语言可以定义为：
# ```
# human = """
# human = 自己 寻找 活动
# 自己 = 我 | 俺 | 我们
# 寻找 = 看看 | 找找 | 想找点
# 活动 = 乐子 | 玩的
# """
# ```
#
# 一个“接待员”的语言可以定义为
# ```
# host = """
# host = 寒暄 报数 询问 业务相关 结尾
# 报数 = 我是 数字 号 ,
# 数字 = 单个数字 | 数字 单个数字
# 单个数字 = 1 | 2 | 3 | 4 | 5 | 6 | 7 | 8 | 9
# 寒暄 = 称谓 打招呼 | 打招呼
# 称谓 = 人称 ,
# 人称 = 先生 | 女士 | 小朋友
# 打招呼 = 你好 | 您好
# 询问 = 请问你要 | 您需要
# 业务相关 = 玩玩 具体业务
# 玩玩 = 耍一耍 | 玩一玩
# 具体业务 = 喝酒 | 打牌 | 打猎 | 赌博
# 结尾 = 吗？"""
#
# ```

# %% [markdown]
# 请定义你自己的语法:

# %% [markdown]
# 第一个语法：

# %%
patient ='''
patient = 打招呼 称呼 陈述
打招呼 = 您好，/你好，/null
称呼 = 护士，/医生，/叔叔，/阿姨，/美女，/帅哥，/null
陈述 = 我 部位 症状 ，怎么办？
部位 = 肚子/牙/腰/腿/头/脚/眼睛/鼻子/耳朵/手
症状 = 疼/痛/痒/难受/不舒服/受伤了/出血了
'''

# %% [markdown]
# 第二个语法：

# %%
nurse = '''
nurse = 打招呼 称呼 问句
打招呼 = 您好，
称呼 = 小朋友，/小妹妹，/小弟弟，/同学，/先生，/女士，/阿姨，/叔叔，/大爷，/爷爷，/奶奶，/null
问句 = 我 动词 谁的 部位 吗？
动词 = 能看看/可以看看
谁的 = 您的/你的
部位 = 肚子/牙/腰/腿/头/脚/眼睛/鼻子/耳朵/手
'''

# %%
def create_grammar(grammar_str, split='=', line_split='\n'):
    grammar = {}
    for line in grammar_str.split(line_split):
        if not line.strip(): continue
        gram, exam = line.split(split)
        grammar[gram.strip()] = [s.split() for s in exam.split('/')]
    return grammar

# %%
import random
choice = random.choice
def generate(gram, target):
    if target not in gram: return target
    expand = [generate(gram, t) for t in choice(gram[target])]
    return ''.join(s for s in expand if s != 'null')
    #return ''.join([s if s != '\n' else '/n' for s in expand if s != 'null'])

# %% [markdown]
# TODO: 然后，使用自己之前定义的generate函数，使用此函数生成句子。

# %%
for i in range(20):
    print(generate(create_grammar(patient, split='='),'patient'))
print('-'*30)
for i in range(20):
    print(generate(create_grammar(nurse, split='='),'nurse'))
# Out:
# 你好，护士，我腰痛，怎么办？
# 你好，护士，我腰痒，怎么办？
# 你好，医生，我眼睛疼，怎么办？
# 您好，护士，我腰不舒服，怎么办？
# 您好，护士，我头难受，怎么办？
# 您好，美女，我腿不舒服，怎么办？
# 你好，阿姨，我脚难受，怎么办？
# 你好，我手不舒服，怎么办？
# 我眼睛不舒服，怎么办？
# 您好，我眼睛出血了，怎么办？
# 护士，我腰受伤了，怎么办？
# 阿姨，我耳朵受伤了，怎么办？
# 帅哥，我腰难受，怎么办？
# 您好，帅哥，我耳朵出血了，怎么办？
# 你好，我头不舒服，怎么办？
# 您好，护士，我肚子难受，怎么办？
# 你好，阿姨，我鼻子出血了，怎么办？
# 你好，护士，我牙难受，怎么办？
# 您好，我手疼，怎么办？
# 您好，护士，我鼻子不舒服，怎么办？
# ------------------------------
# 您好，小妹妹，我可以看看您的腰吗？
# 您好，我可以看看您的腰吗？
# 您好，小弟弟，我可以看看您的腿吗？
# 您好，小朋友，我可以看看你的腰吗？
# 您好，小妹妹，我能看看你的牙吗？
# 您好，奶奶，我可以看看你的鼻子吗？
# 您好，阿姨，我可以看看你的眼睛吗？
# 您好，先生，我能看看您的肚子吗？
# 您好，先生，我可以看看你的腰吗？
# 您好，大爷，我能看看你的肚子吗？
# 您好，同学，我能看看你的手吗？
# 您好，先生，我能看看你的耳朵吗？
# 您好，我能看看您的耳朵吗？
# 您好，同学，我能看看您的头吗？
# 您好，爷爷，我能看看您的牙吗？
# 您好，我能看看您的耳朵吗？
# 您好，大爷，我能看看您的脚吗？
# 您好，爷爷，我能看看你的腰吗？
# 您好，阿姨，我能看看你的腰吗？
# 您好，同学，我能看看您的头吗？

# %% [markdown]
# TODO: 然后，定义一个函数，generate_n，将generate扩展，使其能够生成n个句子:

# %%
def generate_n(n):
    for i in range(n):
        print(generate(create_grammar(patient, split='='),'patient'))
generate_n(20)
# Out:
# 您好，美女，我手疼，怎么办？
# 您好，叔叔，我腿痛，怎么办？
# 你好，阿姨，我牙疼，怎么办？
# 您好，帅哥，我脚痛，怎么办？
# 医生，我腰痛，怎么办？
# 阿姨，我腿受伤了，怎么办？
# 你好，护士，我手受伤了，怎么办？
# 帅哥，我牙痒，怎么办？
# 您好，帅哥，我腰痛，怎么办？
# 护士，我鼻子疼，怎么办？
# 您好，我牙痒，怎么办？
# 您好，叔叔，我手出血了，怎么办？
# 您好，阿姨，我眼睛疼，怎么办？
# 护士，我耳朵不舒服，怎么办？
# 您好，护士，我手难受，怎么办？
# 你好，医生，我牙痛，怎么办？
# 你好，叔叔，我眼睛难受，怎么办？
# 医生，我肚子出血了，怎么办？
# 你好，美女，我肚子受伤了，怎么办？
# 你好，叔叔，我肚子出血了，怎么办？

# %%
file2 = 'E:\\github\\data\\1st_week\\sqlResult_1558435.csv'
import pandas as pd
content = pd.read_csv(file2, encoding = 'gb18030')

# %%
content.head()
# Out:
#       id      author                  source  \
# 0  89617         NaN  快科技@http://www.kkj.cn/
# 1  89616         NaN  快科技@http://www.kkj.cn/
# 2  89615         NaN  快科技@http://www.kkj.cn/
# 3  89614         NaN                     新华社
# 4  89613  胡淑丽_MN7479                   深圳大件事
#
#                                              content  \
# 0  此外，自本周（6月12日）起，除小米手机6等15款机型外，其余机型已暂停更新发布（含开发版/...
# 1  骁龙835作为唯一通过Windows 10桌面平台认证的ARM处理器，高通强调，不会因为只考...
# 2  此前的一加3T搭载的是3400mAh电池，DashCharge快充规格为5V/4A。\r\n...
# 3    这是6月18日在葡萄牙中部大佩德罗冈地区拍摄的被森林大火烧毁的汽车。新华社记者张立云摄\r\n
# 4  （原标题：44岁女子跑深圳约会网友被拒，暴雨中裸身奔走……）\r\n@深圳交警微博称：昨日清...
#
#                                              feature  \
# 0  {"type":"科技","site":"cnbeta","commentNum":"37"...
# 1  {"type":"科技","site":"cnbeta","commentNum":"15"...
# 2  {"type":"科技","site":"cnbeta","commentNum":"18"...
# 3  {"type":"国际新闻","site":"环球","commentNum":"0","j...
# 4  {"type":"新闻","site":"网易热门","commentNum":"978",...
#
#                            title  \
# 0           小米MIUI 9首批机型曝光：共计15款
# 1     骁龙835在Windows 10上的性能表现有望改善
# 2      一加手机5细节曝光：3300mAh、充半小时用1天
# 3  葡森林火灾造成至少62人死亡 政府宣布进入紧急状态（组图）
# 4       44岁女子约网友被拒暴雨中裸奔 交警为其披衣相随
#
#                                                  url
# 0     http://www.cnbeta.com/articles/tech/623597.htm
# 1     http://www.cnbeta.com/articles/tech/623599.htm
# 2     http://www.cnbeta.com/articles/tech/623601.htm
# 3  http://world.huanqiu.com/hot/2017-06/10866126....
# 4  http://news.163.com/17/0618/00/CN617P3Q0001875...

# %%
articles = content['content'].tolist()
print(len(articles))
type(articles)
# Out:
# 89611
# list

# %%
import re
from collections import Counter
import jieba
def token(string):
    return re.findall('\w+', string)

# %%
''.join(token(articles[110]))
# Out:
# '在外国名著麦田里的守望者中作者想要守护麦田里如自己内心一般纯真的孩子们而驻村干部们也在这个炎热的夏天里撸袖子上阵真正做起了村民们的麦田守望者三夏时节不等人你看到了吗不停翻涌起伏仿若铺陈至天边的金黄麦浪中那若隐若现的人影是自治区新闻出版广电局驻和田市肖尔巴格乡合尼村工作队的队员与工作队组织的青年志愿者在这个炎热的夏季他们深入田间地头帮助村民们收割小麦扛起收麦机麦田中的每个人都显得兴致勃勃一天下来就近22亩小麦收割完毕志愿者麦麦提亚森擦去满脸的汗水高兴地告诉驻村队员我们青年志愿者应该多做贡献为村里的脱贫致富出把力工作队带着我们为村里的老人服务看到那些像我爷爷奶奶一样的老人赞许感谢的目光我体会到了帮助他人的快乐自治区新闻出版广电局驻村工作队孙敏艾力依布拉音麦收时节我们在一起6月中旬的和田墨玉麦田金黄静待收割6月14日15日两天自治区高级人民法院驻和田地区墨玉县吐外特乡罕勒克艾日克村工作队与48名村民志愿者一道帮助村里29户有需要
# %%
articles_clean = [''.join(token(str(s))) for s in articles]

# %%
len(articles_clean)
# Out:
# 89611

# %%
with open('article_9k.txt', 'w') as f:
    for a in articles_clean:
        f.write(a + '\n')

# %%
def cut(string): return list(jieba.cut(string))

# %%
TOKEN = []
for i, line in enumerate((open('article_9k.txt'))):
    if i % 10000 == 0: print(i)
    #if i > 1000: break
    TOKEN += cut(line)
# Out:
# 0
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000

# %%
words_count = Counter(TOKEN)

# %%
words_count.most_common(10)
# Out:
# [('的', 703716),
#  ('n', 382020),
#  ('在', 263597),
#  ('月', 189330),
#  ('日', 166300),
#  ('新华社', 142462),
#  ('和', 134061),
#  ('年', 123106),
#  ('了', 121938),
#  ('是', 100909)]

# %%
frequency = [f for w, f in words_count.most_common(100)]
x = [i for i in range(100)]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import numpy as np
plt.plot(x,np.log(frequency))

# %%
def prob_1(word):
    return words_count[word]/len(TOKEN)
prob_1("我们")
# Out:
# 0.0011341645999654677

# %%
TOKEN = [str(s) for s in TOKEN]

# %%
TOKEN[:10]
# Out:
# ['此外', '自', '本周', '6', '月', '12', '日起', '除', '小米', '手机']

# %%
TOKEN_2_GRAM = [
    ''.join(TOKEN[i:i+2]) for i in range(len(TOKEN[:-2]))
]
TOKEN_2_GRAM[:10]
# Out:
# ['此外自', '自本周', '本周6', '6月', '月12', '12日起', '日起除', '除小米', '小米手机', '手机6']

# %%
words_count_2 = Counter(TOKEN_2_GRAM)

# %%
def prob_2(word1, word2):
    if (word1 + word2) in words_count_2: return words_count_2[word1 + word2]/len(TOKEN_2_GRAM
)
    else:
        return 1/len(TOKEN_2_GRAM)

# %%
prob_2('我们','在')
# Out:
# 3.0536514065072974e-05

# %%
def get_probability(sentence):
    words = cut(sentence)
    sentence_pro = 1
    for i, word in enumerate(words[:-1]):
        next_ = words[i+1]
        probability = prob_2(word, next_)
        sentence_pro *= probability
    return sentence_pro

# %%
get_probability('我今天心情很不好')
# Out:
# 8.743133061159471e-26

# %%
get_probability('今儿我心情不很好')
# Out:
# 1.5439022221101235e-32

# %%
generate(create_grammar(patient, split='='),'patient')
# Out:
# '美女，我脚痛，怎么办？'

# %%
for sen in [generate(create_grammar(patient, split='='),'patient') for i in range(10)]:
    print(f'sentence: {sen} with Prb: {get_probability(sen)}')
# Out:
# sentence: 医生，我手出血了，怎么办？ with Prb: 1.8978429769636202e-51
# sentence: 您好，叔叔，我脚难受，怎么办？ with Prb: 1.0772027650436719e-58
# sentence: 你好，我牙出血了，怎么办？ with Prb: 1.8978429769636202e-51
# sentence: 你好，阿姨，我手痛，怎么办？ with Prb: 1.0772027650436719e-58
# sentence: 阿姨，我手不舒服，怎么办？ with Prb: 1.1956410754870809e-49
# sentence: 美女，我牙痒，怎么办？ with Prb: 5.890957807196747e-37
# sentence: 您好，美女，我头不舒服，怎么办？ with Prb: 3.8519016641237356e-64
# sentence: 阿姨，我鼻子痒，怎么办？ with Prb: 1.8978429769636202e-51
# sentence: 您好，护士，我头痒，怎么办？ with Prb: 1.0772027650436719e-58
# sentence: 护士，我手难受，怎么办？ with Prb: 3.3436675824575257e-44

# %% [markdown]
# #### 2. 使用新数据源完成语言模型的训练

# %% [markdown]
# 按照我们上文中定义的`prob_2`函数，我们更换一个文本数据源，获得新的Language Model:
#
# 1. 下载文本数据集（你可以在以下数据集中任选一个，也可以两个都使用）
#     + 可选数据集1，保险行业问询对话集： https://github.com/Computing-Intelligence/insuranceqa-corpus-zh/raw/release/corpus/pool/train.txt.gz
#     + 可选数据集2：豆瓣评论数据集：https://github.com/Computing-Intelligence/datasource/raw/master/movie_comments.csv
# 2. 修改代码，获得新的**2-gram**语言模型
#     + 进行文本清洗，获得所有的纯文本
#     + 将这些文本进行切词
#     + 送入之前定义的语言模型中，判断文本的合理程度

# %%
import re
from collections import Counter
import jieba
def token(string):
    return re.findall('\w+', string)

# %%
file2 = 'movie_comments.txt'
import pandas as pd
content = pd.read_csv(file2, encoding = 'utf-8')
content = content['comment'].tolist()
content = ''.join(s for s in content)
content = ''.join(token(content))
content = cut(content)
print(content)
# Out:
# ['吴京', '意淫', '到', '了', '脑残', '的', '地步', '看', '了', '恶心', '想', '吐', '首映礼', '看', '的', '太', '恐怖', '了', '这个', '电影', '不讲道理', '的', '完全', '就是', '吴京', '在', '实现', '他', '这个', '小', '粉红', '的', '英雄', '梦', '各种', '装备', '轮番', '上场', '视', '物理', '逻辑', '于', '不顾', '不得不', '说', '有钱', '真', '好', '随意', '胡闹', '吴京', '的', '炒作', '水平', '不输', '冯小刚', '但小刚', '至少', '不会', '用', '主旋律', '来', '炒作', '吴京', '让', '人', '看', '了', '不', '舒服', '为了', '主旋律', '而', '主旋律', '为了', '煽情', '而', '煽情', '让', '人', '觉得', '他', '是', '个', '大', '做作', '大', '谎言', '家', '729', '更新', '片子', '整体', '不如', '湄公河', '行动', '1', '整体', '不够', '流畅', '编剧', '有毒', '台词', '尴尬', '2', '刻意', '做作', '的', '主旋律', '煽情', '显得', '如此', '不合时宜', '而', '又', '多余', '凭良心说', '好', '看到', '不像', '战狼', '1', '的', '续集', '完虐', '湄公河', '行动', '中二得', '很', '犯', '我', '中华', '者', '虽远必', '诛', '吴京', '比', '这句', '话', '还要', '意淫', '一百倍', '脑子', '是', '个', '好', '东西', '希望', '编剧', '们', '都', '能', '有', '三星', '半', '实打实', '的', '7', '分', '第一集', '在', '爱国', '主旋律', '内部', '做', '着', '各种', '置换', '与', '较劲', '但', '第二集', '才', '真正', '显露', '吴京', '的', '野心', '他', '终于', '抛弃', '李忠志', '了', '新增', '外来', '班底', '让', '硬件', '实力', '有', '机会', '和', '国际', '接轨', '开篇', '水下', '长镜头', '和', '诸如', '铁丝网', '拦截', 'RPG', '弹头', '的', '细节', '设计', '都', '让', '国产', '动作片', '重新', '封顶', '在', '理念', '上', '它', '甚至', '做到', '绣春刀', '2', '最', '想做到', '的', '那', '部分', '开篇', '长镜头', '惊险', '大气', '引人入胜', '结合', '了', '水平', '不俗', '的', '快', '剪下', '实打实', '的', '真刀真枪', '让', '人', '不禁', '热血沸腾', '特别', '弹簧床', '架', '挡', '炸弹', '空手', '接', '碎玻璃', '弹匣', '割喉', '等', '帅', '得', '飞起', '就算', '前半段', '铺垫', '节奏', '散漫', '主角', '光环', '开太大', '等', '也', '不怕', '作为', '一个', '中国', '人', '两个', '小时', '弥漫着', '中国', '强大', '得', '不可', '侵犯', '的', '氛围', '还是', '让', '那颗', '民族', '自豪', '心', '砰砰', '砰', '跳个', '不停', '15100', '吴京', '的', '冷峰', '在', '这部', '里', '即', '像', '成龙', '又', '像杰', '森斯坦', '森但', '体制', '外', '的', '同', '类型', '电影', '主角', '总是', '代表', '个人', '无能', '的', '政府', '需要', '求助于', '这些', '英雄', '才能', '解决', '难题', '体现', '的', '是', '个人', '的', '价值', '所以', '主旋律', '照抄', '这种', '模式', '实际上', '是', '有', '问题', '的', '我们', '以前', '嘲笑', '个人', '英雄主义', '却', '没想到', '捆绑', '爱国主义', '的', '全能', '战士', '更加', '难以', '下咽', '犯', '我', '中华', '者', '虽远必', '诛', '是', '有', '多', '无脑', '才', '信', '这句', '话', '这部', '戏', '让', '人', '看', '的', '热血沸腾', '对', '吴京路', '转粉', '最后', '的', '彩蛋', '让', '我们', '没有', '理由', '不', '期待', '下', '一部', '假', '嗨', '特别', '恶心', '的', '电影', '有', '几处', '情节', '设置', '过于', '尴尬', '彰显', '国家', '自豪感', '的', '部分', '稍显', '突兀', '就是', '一部', '爽片', '打戏', '挺燃', '但是', '故事', '一般', '达康', '书记', '不', '合适', '这个', '角色', '赵', '东来', '倒', '是', '很', '合适', '张瀚', '太太', '太违', '和', '了', '分', '分钟', '穿越', '回', '偶像剧', '赵', '东来', '达康', '书记', '我们', '接到', '在', '非洲', '卧底', '的', '冷锋', '报告', '丁义珍', '现在', '非洲', '我们', '请求', '抓捕', '李达康', '东来', '这件', '事先', '不要', '声张', '特别', '是', '别', '让', '省厅', '知道', '就', '你', '和', '我', '一起', '去', '非洲', '加上', '冷锋', '同志', '三人', '逮捕', '丁义珍', '这次', '行', '就', '叫', '战狼', '2', '吧', '下', '一部', '拍', '喜剧', '吧', '整个', '片子', '真', '感觉', '挺', '搞笑', '的', '战狼', '2', '里', '吴京', '这么', '能', '打', '他', '打', '得', '过', '徐晓冬', '么', '心往', '一处', '想劲往', '一处', '使', '就', '能', '实现', '我们', '的', '梦想', '看吧', '比', '第一部', '好太多', '了', '谢谢', '美队', '的', '动作', '指导', '这', '都', '能', '火', '是', '我', '没见识', '开头', '的', '水下', '长', '对决', '戏可算', '华语', '电影', '的', '顶尖', '存在', '驱逐舰', '导弹', '和', '坦克', '在', '商业片', '里', '这么', '狂用', '也', '是', '了', '得', '镜头', '运用', '和', '笑', '点', '插入', '都', '很', '好莱坞', '爆米花', '不功', '不过', '从头', '打到', '尾', '是', '真', '拼', '虽然', '镜头', '也', '有略', '乱', '时', '因为', '没', '啥', '期望值', '所以', '被', '吴京', '的', '野心', '吓了一跳', '吴刚', '于', '谦和', '丁海峰', '老', '三位', '像', '炖', '烂熟', '的', '牛筋', '嚼', '着', '就', '舒服', '很', '用心', '啊', '吴京', '导演', '小看', '你', '了', '确实', '在', '导演', '上', '下功夫', '了', '拉', '片子', '了', '知道', '借鉴', '是', '好', '的', '至于', '大家',
# ['吴京意淫', '意淫到', '到了', '了脑残', '脑残的', '的地步', '地步看', '看了', '了恶心', '恶心想']

# %%
def prob_2(word1, word2):
    if (word1 + word2) in words_count_2: return words_count_2[word1 + word2]/len(TOKEN_2_GRAM
)
    else:
        return 1/len(TOKEN_2_GRAM)

# %%
def get_probability(sentence):
    words = cut(sentence)
    sentence_pro = 1
    for i, word in enumerate(words[:-1]):
        next_ = words[i+1]
        probability = prob_2(word, next_)
        sentence_pro *= probability
    return sentence_pro

# %%
for sen in [generate(create_grammar(patient, split='='),'patient') for i in range(10)]:
    print(f'sentence: {sen} with Prb: {get_probability(sen)}')
# Out:
# sentence: 医生，我脚疼，怎么办？ with Prb: 3.115429635996089e-30
# sentence: 阿姨，我牙疼，怎么办？ with Prb: 3.115429635996089e-30
# sentence: 您好，护士，我手受伤了，怎么办？ with Prb: 8.798262252314707e-44
# sentence: 您好，叔叔，我耳朵痒，怎么办？ with Prb: 5.498913907696692e-45
# sentence: 您好，美女，我牙痒，怎么办？ with Prb: 3.7650516472048063e-35
# sentence: 您好，护士，我肚子难受，怎么办？ with Prb: 5.498913907696692e-45
# sentence: 你好，护士，我头痛，怎么办？ with Prb: 4.550131302062705e-40
# sentence: 我脚痛，怎么办？ with Prb: 2.1331036782263316e-20
# sentence: 您好，护士，我腿痒，怎么办？ with Prb: 5.498913907696692e-45
# sentence: 您好，护士，我鼻子疼，怎么办？ with Prb: 5.498913907696692e-45

# %% [markdown]
# #### 3. 获得最优质的的语言

# %% [markdown]
# 当我们能够生成随机的语言并且能判断之后，我们就可以生成更加合理的语言了。请定义 generate_best 函数，该函数输入一个语法 + 语言模型，能够生成**n**个句子，并能选择一个最合理的句子:

# %% [markdown]
# 提示，要实现这个函数，你需要Python的sorted函数

# %%
sorted([1, 3, 5, 2])

# %% [markdown]
# 这个函数接受一个参数key，这个参数接受一个函数作为输入，例如

# %%
sorted([(2, 5), (1, 4), (5, 0), (4, 4)], key=lambda x: x[0])
# Out:
# [(1, 4), (2, 5), (4, 4), (5, 0)]

# %% [markdown]
# 能够让list按照第0个元素进行排序.

# %%
sorted([(2, 5), (1, 4), (5, 0), (4, 4)], key=lambda x: x[1])
# Out:
# [(5, 0), (1, 4), (4, 4), (2, 5)]

# %% [markdown]
# 能够让list按照第1个元素进行排序.

# %%
sorted([(2, 5), (1, 4), (5, 0), (4, 4)], key=lambda x: x[1], reverse=True)

# %% [markdown]
# 能够让list按照第1个元素进行排序, 但是是递减的顺序。

# %% [markdown]
# >

# %%
def generate_best(number_of_centences): 
    sentences = []
    for sen in [generate(create_grammar(patient, split='='),'patient') for i in range(number_of_centences)]:
        print(f'sentence: {sen} with Prb: {get_probability(sen)}')
        sentences.append((sen, get_probability(sen)))
    #print(sentences)
    sentences = sorted(sentences, key = lambda x:x[1])
    print("\n"*3)
    print(f"The best sentences is: {sentences[-1][0]} \n")

# %% [markdown]
# 好了，现在我们实现了自己的第一个AI模型，这个模型能够生成比较接近于人类的语言。

# %%
generate_best(100)
# Out:
# sentence: 你好，我鼻子疼，怎么办？ with Prb: 3.7650516472048063e-35
# sentence: 帅哥，我肚子出血了，怎么办？ with Prb: 4.550131302062705e-40
# sentence: 阿姨，我腰难受，怎么办？ with Prb: 3.7650516472048063e-35
# sentence: 您好，美女，我眼睛痛，怎么办？ with Prb: 1.0997827815393384e-44
# sentence: 医生，我鼻子痒，怎么办？ with Prb: 3.7650516472048063e-35
# sentence: 你好，医生，我腿出血了，怎么办？ with Prb: 6.645534415798579e-50
# sentence: 美女，我腰痛，怎么办？ with Prb: 3.115429635996089e-30
# sentence: 你好，叔叔，我眼睛痛，怎么办？ with Prb: 1.0997827815393384e-44
# sentence: 您好，医生，我鼻子疼，怎么办？ with Prb: 5.498913907696692e-45
# sentence: 医生，我牙出血了，怎么办？ with Prb: 3.7650516472048063e-35
# sentence: 你好，护士，我肚子受伤了，怎么办？ with Prb: 1.0632855065277726e-48
# sentence: 我头不舒服，怎么办？ with Prb: 1.6240728461588343e-23
# sentence: 我眼睛疼，怎么办？ with Prb: 5.155786813202648e-25
# sentence: 医生，我头疼，怎么办？ with Prb: 3.115429635996089e-30
# sentence:
怎么办？ with Prb: 3.7650516472048063e-35
# sentence: 医生，我手痒，怎么办？ with Prb: 3.115429635996089e-30
# sentence: 我头出血了，怎么办？ with Prb: 2.577893406601324e-25
# sentence: 叔叔，我牙痛，怎么办？ with Prb: 3.115429635996089e-30
# sentence: 你好，我手出血了，怎么办？ with Prb: 3.7650516472048063e-35
# sentence: 阿姨，我眼睛受伤了，怎么办？ with Prb: 1.4560420166600656e-38
# sentence: 您好，医生，我耳朵受伤了，怎么办？ with Prb: 1.0632855065277726e-48
# sentence: 您好，我脚不舒服，怎么办？ with Prb: 2.3719825377390282e-33
# sentence: 您好，我腿不舒服，怎么办？ with Prb: 2.866582720299505e-38
# sentence: 您好，美女，我眼睛痛，怎么办？ with Prb: 1.0997827815393384e-44
# sentence: 您好，我脚不舒服，怎么办？ with Prb: 2.3719825377390282e-33
# sentence: 你好，阿姨，我眼睛痒，怎么办？ with Prb: 1.0997827815393384e-44
# sentence: 叔叔，我头疼，怎么办？ with Prb: 3.115429635996089e-30
# sentence: 护士，我牙痒，怎么办？ with Prb: 2.577893406601324e-25
# sentence: 您好，帅哥，我头痛，怎么办？ with Prb: 4.550131302062705e-40
# sentence: 您好，帅哥，我牙痒，怎么办？ with Prb: 3.7650516472048063e-35
# sentence: 您好，我鼻子疼，怎么办？ with Prb: 3.7650516472048063e-35
# sentence: 你好，美女，我头痒，怎么办？ with Prb: 4.550131302062705e-40
# sentence: 您好，帅哥，我耳朵受伤了，怎么办？ with Prb: 1.0632855065277726e-48
# sentence: 帅哥，我腰痒，怎么办？ with Prb: 3.7650516472048063e-35
# sentence: 护士，我腰难受，怎么办？ with Prb: 3.7650516472048063e-35
# sentence: 您好，我腰受伤了，怎么办？ with Prb: 7.280210083300328e-39
#
#
#
#
# The best sentences is: 我肚子痛，怎么办？

# %% [markdown]
# >

# %% [markdown]
# Q: 这个模型有什么问题？ 你准备如何提升？

# %% [markdown]
# Ans:句子越短，概率越大，可以把概率乘以句子的字数或其他算法来补偿

# %% [markdown]
# >

# %% [markdown]
# ##### 以下内容为可选部分，对于绝大多数同学，能完成以上的项目已经很优秀了，下边的内容如果你还有精力可以试试，但不是必须的。

# %% [markdown]
# #### 4. (Optional) 完成基于Pattern Match的语句问答
# > 我们的GitHub仓库中，有一个assignment-01-optional-pattern-match，这个难度较大，感兴趣的同学可以挑战一下。

# %% [markdown]
# #### 5. (Optional) 完成阿兰图灵机器智能原始论文的阅读
# 1. 请阅读阿兰图灵关于机器智能的原始论文：https://github.com/Computing-Intelligence/References/blob/master/AI%20%26%20Machine%20Learning/Computer%20Machinery%20and%20Intelligence.pdf
# 2. 并按照GitHub仓库中的论文阅读模板，填写完毕后发送给我: mqgao@kaikeba.com 谢谢

# %% [markdown]
# >

# %% [markdown]
# 各位同学，我们已经完成了自己的第一个AI模型，大家对人工智能可能已经有了一些感觉，人工智能的核心就是，我们如何设计一个模型、程序，在外部的输入变化的时候，我们的程序不变，依然能够解决问题。人工智能是一个很大的领域，目前大家所熟知的深度学习只是其中一小部分，之后也肯定会有更多的方法提出来，但是大家知道人工智能的目标，就知道了之后进步的方向。

# %% [markdown]
# 然后，希望大家对AI不要有恐惧感，这个并不难，大家加油！

# %% [markdown]
# >

# %% [markdown]
# ![](https://timgsa.baidu.com/timg?image&quality=80&size=b9999_10000&sec=1561828422005&di=48d19c16afb6acc9180183a6116088ac&imgtype=0&src=http%3A%2F%2Fb-ssl.duitang.com%2Fuploads%2Fitem%2F201807%2F28%2F20180728150843_BECNF.thumb.224_0.jpeg)
